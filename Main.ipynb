# %%
import pandas as pd
pd.set_option("display.max_rows", 101)
pd.set_option("display.max_columns", 101)

import matplotlib.pyplot as plt

import example_module as em

import matplotlib.patches as patches
from matplotlib.lines import Line2D

# %%
#Inspiration from https://github.com/tuangauss/DataScienceProjects/blob/master/Python/football_visual.ipynb

def draw_TennisCourt(ax): 
    
#The outline and centre line

    plt.plot([0,0],[0,36], color="black")
    plt.plot([0,78],[36,36], color="black")
    plt.plot([78,78],[0,36], color="black")
    plt.plot([78,0],[0,0], color="black")
    plt.plot([39,39],[0,36], color="black")
    
#The singles sidelines

    plt.plot([0,78],[4.5,4.5], color="black")
    plt.plot([0,78],[31.5,31.5], color="black")
    
#The service lines
    
    plt.plot([18,18],[4.5,31.5], color="black")
    plt.plot([60,60],[4.5,31.5], color="black")
    plt.plot([18,60],[18,18], color="black")

# %%
fig=draw_TennisCourt()

# %%
fig=plt.figure()
fig.set_size_inches(19.5, 9) #sets viewing dimensions
ax=fig.add_subplot(1,1,1)
ax.set_title('Tennis Court')
draw_TennisCourt()
fig.savefig("Tennis_Court.png") #exports the image
